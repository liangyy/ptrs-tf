# %%
import sys, re
sys.path.append("../code/")
import lib_LinearAlgebra, lib_cnnPTRS, util_hdf5, util_misc, util_Stats
import tensorflow as tf
import numpy as np
import pandas as pd
import h5py, yaml
import matplotlib.pyplot as plt
from importlib import reload  
lib_LinearAlgebra = reload(lib_LinearAlgebra)
lib_cnnPTRS = reload(lib_cnnPTRS)
util_hdf5 = reload(util_hdf5)
util_misc = reload(util_misc)
util_Stats = reload(util_Stats)
import logging
logging.basicConfig(
    level = logging.INFO, 
    stream = sys.stderr, 
    format = '%(asctime)s  %(message)s',
    datefmt = '%Y-%m-%d %I:%M:%S %p'
)

# %%
def get_tss(start, end, strand):
    if strand == '+':
        return start
    else:
        return end
def chr2num(chrm):
    if 'X' in chrm:
        chrm = 23
    elif 'Y' in chrm:
        chrm = 24
    elif 'M' in chrm:
        chrm = 25
    else:
        chrm = int(re.sub('chr', '', chrm))
    return chrm

df_gene = pd.read_table('https://bitbucket.org/yanyul/rotation-at-imlab/raw/85a3fbe8f08df7c67265fed69569b7ea554d4e12/data/annotations_gencode_v26.tsv')


df_gene['tss'] = df_gene[['start', 'end', 'strand']].apply(lambda x: get_tss(x.start, x.end, x.strand), axis = 1)

df_gene['chr_num'] = df_gene[['chromosome']].apply(lambda x: chr2num(x.chromosome), axis = 1)

df_gene.sort_values(['chr_num', 'tss'], ascending = [True, True], inplace = True) 

df_gene = df_gene.reset_index(drop = True)

df_gene['rank'] = df_gene.index


with h5py.File('/vol/bmd/yanyul/UKB/predicted_expression_tf2/ukb_imp_x_ctimp_Whole_Blood_Chinese.hdf5', 'r') as f:
    col_genes = f['columns_x'][...]
col_genes_cleaned = [ i.astype(str).split('.')[0] for i in col_genes ]
df_col_genes = pd.DataFrame({'gene_id': col_genes_cleaned, 'col_idx': [ i for i in range(len(col_genes_cleaned)) ]})

df_gene_joined = df_gene.join(df_col_genes.set_index('gene_id'), on = 'gene_id')

df_gene_joined = df_gene_joined.loc[df_gene_joined['gene_id'].isin(df_col_genes['gene_id'].to_list())].reset_index(drop = True)


x_indice = [ int(i) for i in df_gene_joined['col_idx'].to_list() ]

hdf5_test = '/vol/bmd/yanyul/UKB/predicted_expression_tf2/ukb_imp_x_ctimp_Whole_Blood_British.hdf5'
scheme_yaml = '../misc_files/data_scheme.yaml'
feature_dic = util_hdf5.read_yaml(scheme_yaml)
with h5py.File(hdf5_test, 'r') as f:
    features = f['columns_y'][:].astype('str')
    y = f['y'][:]
covar_indice = np.where(np.isin(features, feature_dic['covar_names']))[0]
trait_indice = np.where(np.isin(features, feature_dic['outcome_names']))[0]
# load data_scheme for training
batch_size = 4096 # 512  # 4096 # 280
print(f'batch_size in the Chinese set (for code testing) is {batch_size}')
data_scheme, sample_size = util_hdf5.build_data_scheme(
    hdf5_test, 
    scheme_yaml, 
    batch_size = batch_size, 
    inv_norm_y = True
)


### IMPORTANT ###
# set x_indice
data_scheme.x_indice = x_indice

# set validation and test set as the first and second batch
dataset_valid = data_scheme.dataset.take(1)
data_scheme.dataset = data_scheme.dataset.skip(1)
dataset_test = data_scheme.dataset.take(1)
data_scheme.dataset = data_scheme.dataset.skip(1)
dataset_insample = data_scheme.dataset.take(1)


ntrain = sample_size - 2 * batch_size
train_batch = batch_size
# Out:
# batch_size in the Chinese set (for code testing) is 4096

# %% [markdown]
# # CNN

# %%
cnn_model = util_misc.load_ordered_yaml('../misc_files/cnn_ptrs_1.yaml')
cnn = lib_cnnPTRS.cnnPTRS(cnn_model, data_scheme, 'temp.h5', normalizer = True)
cnn.model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7044, 1)]    0
# __________________________________________________________________________________________________
# layer1_conv (Conv1D)            (None, 3519, 32)     288         input_1[0][0]
# __________________________________________________________________________________________________
# layer1_maxpool (MaxPooling1D)   (None, 1759, 32)     0           layer1_conv[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 56288)        0           layer1_maxpool[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# ptrs_dense_0 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_1 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_2 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_3 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_4 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_5 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_6 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_7 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_8 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_9 (Dense)            (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_10 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_11 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_12 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_13 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_14 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_15 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_16 (Dense)           (None, 1)            56288       flatten[0][0]
# __________________________________________________________________________________________________
# covar_dense_0 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_1 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_2 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_3 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_4 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_5 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_6 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_7 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_8 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_9 (Dense)           (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_10 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_11 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_12 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_13 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_14 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_15 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# covar_dense_16 (Dense)          (None, 1)            26          input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 17)           0           ptrs_dense_0[0][0]
#                                                                  ptrs_dense_1[0][0]
#                                                                  ptrs_dense_2[0][0]
#                                                                  ptrs_dense_3[0][0]
#                                                                  ptrs_dense_4[0][0]
#                                                                  ptrs_dense_5[0][0]
#                                                                  ptrs_dense_6[0][0]
#                                                                  ptrs_dense_7[0][0]
#                                                                  ptrs_dense_8[0][0]
#                                                                  ptrs_dense_9[0][0]
#                                                                  ptrs_dense_10[0][0]
#                                                                  ptrs_dense_11[0][0]
#                                                                  ptrs_dense_12[0][0]
#                                                                  ptrs_dense_13[0][0]
#                                                                  ptrs_dense_14[0][0]
#                                                                  ptrs_dense_15[0][0]
#                                                                  ptrs_dense_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 17)           0           covar_dense_0[0][0]
#                                                                  covar_dense_1[0][0]
#                                                                  covar_dense_2[0][0]
#                                                                  covar_dense_3[0][0]
#                                                                  covar_dense_4[0][0]
#                                                                  covar_dense_5[0][0]
#                                                                  covar_dense_6[0][0]
#                                                                  covar_dense_7[0][0]
#                                                                  covar_dense_8[0][0]
#                                                                  covar_dense_9[0][0]
#                                                                  covar_dense_10[0][0]
#                                                                  covar_dense_11[0][0]
#                                                                  covar_dense_12[0][0]
#                                                                  covar_dense_13[0][0]
#                                                                  covar_dense_14[0][0]
#                                                                  covar_dense_15[0][0]
#                                                                  covar_dense_16[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 17)           0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
# ==================================================================================================
# Total params: 957,626
# Trainable params: 957,626
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
cnn_model = util_misc.load_ordered_yaml('../misc_files/cnn_ptrs_2.yaml')
cnn = lib_cnnPTRS.cnnPTRS(cnn_model, data_scheme, 'temp.h5', normalizer = True)
cnn.model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 7044, 1)]    0
# __________________________________________________________________________________________________
# layer1_conv (Conv1D)            (None, 3519, 32)     288         input_3[0][0]
# __________________________________________________________________________________________________
# layer1_maxpool (MaxPooling1D)   (None, 1759, 32)     0           layer1_conv[0][0]
# __________________________________________________________________________________________________
# layer2_conv (Conv1D)            (None, 876, 32)      8224        layer1_maxpool[0][0]
# __________________________________________________________________________________________________
# layer2_maxpool (MaxPooling1D)   (None, 438, 32)      0           layer2_conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 14016)        0           layer2_maxpool[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# ptrs_dense_0 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_1 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_2 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_3 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_4 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_5 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_6 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_7 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_8 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_9 (Dense)            (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_10 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_11 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_12 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_13 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_14 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_15 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_16 (Dense)           (None, 1)            14016       flatten_1[0][0]
# __________________________________________________________________________________________________
# covar_dense_0 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_1 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_2 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_3 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_4 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_5 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_6 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_7 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_8 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_9 (Dense)           (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_10 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_11 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_12 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_13 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_14 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_15 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_16 (Dense)          (None, 1)            26          input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 17)           0           ptrs_dense_0[0][0]
#                                                                  ptrs_dense_1[0][0]
#                                                                  ptrs_dense_2[0][0]
#                                                                  ptrs_dense_3[0][0]
#                                                                  ptrs_dense_4[0][0]
#                                                                  ptrs_dense_5[0][0]
#                                                                  ptrs_dense_6[0][0]
#                                                                  ptrs_dense_7[0][0]
#                                                                  ptrs_dense_8[0][0]
#                                                                  ptrs_dense_9[0][0]
#                                                                  ptrs_dense_10[0][0]
#                                                                  ptrs_dense_11[0][0]
#                                                                  ptrs_dense_12[0][0]
#                                                                  ptrs_dense_13[0][0]
#                                                                  ptrs_dense_14[0][0]
#                                                                  ptrs_dense_15[0][0]
#                                                                  ptrs_dense_16[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 17)           0           covar_dense_0[0][0]
#                                                                  covar_dense_1[0][0]
#                                                                  covar_dense_2[0][0]
#                                                                  covar_dense_3[0][0]
#                                                                  covar_dense_4[0][0]
#                                                                  covar_dense_5[0][0]
#                                                                  covar_dense_6[0][0]
#                                                                  covar_dense_7[0][0]
#                                                                  covar_dense_8[0][0]
#                                                                  covar_dense_9[0][0]
#                                                                  covar_dense_10[0][0]
#                                                                  covar_dense_11[0][0]
#                                                                  covar_dense_12[0][0]
#                                                                  covar_dense_13[0][0]
#                                                                  covar_dense_14[0][0]
#                                                                  covar_dense_15[0][0]
#                                                                  covar_dense_16[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 17)           0           concatenate_2[0][0]
#                                                                  concatenate_3[0][0]
# ==================================================================================================
# Total params: 247,226
# Trainable params: 247,226
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # MLP

# %%
mlp_model = util_misc.load_ordered_yaml('../misc_files/mlp_ptrs_1.yaml')
mlp = lib_cnnPTRS.mlpPTRS(mlp_model, data_scheme, 'temp.h5', normalizer = True)
mlp.model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 7044, 1)]    0
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 7044)         0           input_5[0][0]
# __________________________________________________________________________________________________
# layer1_dense (Dense)            (None, 100)          704500      flatten_2[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# ptrs_dense_0 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_1 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_2 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_3 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_4 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_5 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_6 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_7 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_8 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_9 (Dense)            (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_10 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_11 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_12 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_13 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_14 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_15 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_16 (Dense)           (None, 1)            100         layer1_dense[0][0]
# __________________________________________________________________________________________________
# covar_dense_0 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_1 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_2 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_3 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_4 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_5 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_6 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_7 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_8 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_9 (Dense)           (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_10 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_11 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_12 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_13 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_14 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_15 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# covar_dense_16 (Dense)          (None, 1)            26          input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 17)           0           ptrs_dense_0[0][0]
#                                                                  ptrs_dense_1[0][0]
#                                                                  ptrs_dense_2[0][0]
#                                                                  ptrs_dense_3[0][0]
#                                                                  ptrs_dense_4[0][0]
#                                                                  ptrs_dense_5[0][0]
#                                                                  ptrs_dense_6[0][0]
#                                                                  ptrs_dense_7[0][0]
#                                                                  ptrs_dense_8[0][0]
#                                                                  ptrs_dense_9[0][0]
#                                                                  ptrs_dense_10[0][0]
#                                                                  ptrs_dense_11[0][0]
#                                                                  ptrs_dense_12[0][0]
#                                                                  ptrs_dense_13[0][0]
#                                                                  ptrs_dense_14[0][0]
#                                                                  ptrs_dense_15[0][0]
#                                                                  ptrs_dense_16[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 17)           0           covar_dense_0[0][0]
#                                                                  covar_dense_1[0][0]
#                                                                  covar_dense_2[0][0]
#                                                                  covar_dense_3[0][0]
#                                                                  covar_dense_4[0][0]
#                                                                  covar_dense_5[0][0]
#                                                                  covar_dense_6[0][0]
#                                                                  covar_dense_7[0][0]
#                                                                  covar_dense_8[0][0]
#                                                                  covar_dense_9[0][0]
#                                                                  covar_dense_10[0][0]
#                                                                  covar_dense_11[0][0]
#                                                                  covar_dense_12[0][0]
#                                                                  covar_dense_13[0][0]
#                                                                  covar_dense_14[0][0]
#                                                                  covar_dense_15[0][0]
#                                                                  covar_dense_16[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 17)           0           concatenate_4[0][0]
#                                                                  concatenate_5[0][0]
# ==================================================================================================
# Total params: 706,642
# Trainable params: 706,642
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mlp_model = util_misc.load_ordered_yaml('../misc_files/mlp_ptrs_2.yaml')
mlp = lib_cnnPTRS.mlpPTRS(mlp_model, data_scheme, 'temp.h5', normalizer = True)
mlp.model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 7044, 1)]    0
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 7044)         0           input_7[0][0]
# __________________________________________________________________________________________________
# layer1_dense (Dense)            (None, 100)          704500      flatten_3[0][0]
# __________________________________________________________________________________________________
# layer2_dense (Dense)            (None, 50)           5050        layer1_dense[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# ptrs_dense_0 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_1 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_2 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_3 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_4 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_5 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_6 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_7 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_8 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_9 (Dense)            (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_10 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_11 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_12 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_13 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_14 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_15 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_16 (Dense)           (None, 1)            50          layer2_dense[0][0]
# __________________________________________________________________________________________________
# covar_dense_0 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_1 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_2 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_3 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_4 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_5 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_6 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_7 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_8 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_9 (Dense)           (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_10 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_11 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_12 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_13 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_14 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_15 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# covar_dense_16 (Dense)          (None, 1)            26          input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 17)           0           ptrs_dense_0[0][0]
#                                                                  ptrs_dense_1[0][0]
#                                                                  ptrs_dense_2[0][0]
#                                                                  ptrs_dense_3[0][0]
#                                                                  ptrs_dense_4[0][0]
#                                                                  ptrs_dense_5[0][0]
#                                                                  ptrs_dense_6[0][0]
#                                                                  ptrs_dense_7[0][0]
#                                                                  ptrs_dense_8[0][0]
#                                                                  ptrs_dense_9[0][0]
#                                                                  ptrs_dense_10[0][0]
#                                                                  ptrs_dense_11[0][0]
#                                                                  ptrs_dense_12[0][0]
#                                                                  ptrs_dense_13[0][0]
#                                                                  ptrs_dense_14[0][0]
#                                                                  ptrs_dense_15[0][0]
#                                                                  ptrs_dense_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17)           0           covar_dense_0[0][0]
#                                                                  covar_dense_1[0][0]
#                                                                  covar_dense_2[0][0]
#                                                                  covar_dense_3[0][0]
#                                                                  covar_dense_4[0][0]
#                                                                  covar_dense_5[0][0]
#                                                                  covar_dense_6[0][0]
#                                                                  covar_dense_7[0][0]
#                                                                  covar_dense_8[0][0]
#                                                                  covar_dense_9[0][0]
#                                                                  covar_dense_10[0][0]
#                                                                  covar_dense_11[0][0]
#                                                                  covar_dense_12[0][0]
#                                                                  covar_dense_13[0][0]
#                                                                  covar_dense_14[0][0]
#                                                                  covar_dense_15[0][0]
#                                                                  covar_dense_16[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 17)           0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
# ==================================================================================================
# Total params: 710,842
# Trainable params: 710,842
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Baseline

# %%
mlp = lib_cnnPTRS.mlpPTRS(None, data_scheme, 'temp.h5', normalizer = True)
mlp.model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 7044, 1)]    0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 7044)         0           input_9[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 25)]         0
# __________________________________________________________________________________________________
# ptrs_dense_0 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_1 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_2 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_3 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_4 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_5 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_6 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_7 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_8 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_9 (Dense)            (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_10 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_11 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_12 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_13 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_14 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_15 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# ptrs_dense_16 (Dense)           (None, 1)            7044        flatten_4[0][0]
# __________________________________________________________________________________________________
# covar_dense_0 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_1 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_2 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_3 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_4 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_5 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_6 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_7 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_8 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_9 (Dense)           (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_10 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_11 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_12 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_13 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_14 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_15 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# covar_dense_16 (Dense)          (None, 1)            26          input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 17)           0           ptrs_dense_0[0][0]
#                                                                  ptrs_dense_1[0][0]
#                                                                  ptrs_dense_2[0][0]
#                                                                  ptrs_dense_3[0][0]
#                                                                  ptrs_dense_4[0][0]
#                                                                  ptrs_dense_5[0][0]
#                                                                  ptrs_dense_6[0][0]
#                                                                  ptrs_dense_7[0][0]
#                                                                  ptrs_dense_8[0][0]
#                                                                  ptrs_dense_9[0][0]
#                                                                  ptrs_dense_10[0][0]
#                                                                  ptrs_dense_11[0][0]
#                                                                  ptrs_dense_12[0][0]
#                                                                  ptrs_dense_13[0][0]
#                                                                  ptrs_dense_14[0][0]
#                                                                  ptrs_dense_15[0][0]
#                                                                  ptrs_dense_16[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 17)           0           covar_dense_0[0][0]
#                                                                  covar_dense_1[0][0]
#                                                                  covar_dense_2[0][0]
#                                                                  covar_dense_3[0][0]
#                                                                  covar_dense_4[0][0]
#                                                                  covar_dense_5[0][0]
#                                                                  covar_dense_6[0][0]
#                                                                  covar_dense_7[0][0]
#                                                                  covar_dense_8[0][0]
#                                                                  covar_dense_9[0][0]
#                                                                  covar_dense_10[0][0]
#                                                                  covar_dense_11[0][0]
#                                                                  covar_dense_12[0][0]
#                                                                  covar_dense_13[0][0]
#                                                                  covar_dense_14[0][0]
#                                                                  covar_dense_15[0][0]
#                                                                  covar_dense_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 17)           0           concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
# ==================================================================================================
# Total params: 120,190
# Trainable params: 120,190
# Non-trainable params: 0
# __________________________________________________________________________________________________
